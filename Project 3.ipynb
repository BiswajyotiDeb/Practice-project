# %% [markdown]
# # Importing modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

# %% [markdown]
# # Loading the Dataset

# %%
df=pd.read_csv('winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # Checking null values in the dataframe

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#data visualisation
sns.heatmap(df.isnull(),cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outcome: There is no null value in the data set

# %% [markdown]
# # Data Frame Description

# %% [markdown]
# The dataset is related to red and white variants of the Portuguese "Vinho Verde" wine. Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# Attribute Information
#
# Input variables (based on physicochemical tests):
# 1 - fixed acidity
# 2 - volatile acidity
# 3 - citric acid
# 4 - residual sugar
# 5 - chlorides
# 6 - free sulfur dioxide
# 7 - total sulfur dioxide
# 8 - density
# 9 - pH
# 10 - sulphates
# 11 - alcohol
#
# Output variable (based on sensory data):
# 12 - quality (score between 0 and 10)

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# There are 1599 rows and 12 attributes

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# # Data Set Description

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#visualisation
plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2),annot=True,linewidth=1,linecolor='yellow',fmt='.2f')
plt.show()

# %% [markdown]
# key observation:
# 1. the mean is more than median(50th percentile)in all the columns.
# 2. there is large difference in 75% and max in residual sugar,free sulfer dioxide,total sulfer dioxide.
# 3. the 1 and 2 observations suggest that there are extreme outliers present in these three columns.

# %% [markdown]
# # EDA:

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['quality'])
plt.show()

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# quality scores ranges from 3 to 8, where 3 is low quality and 8 is the best quality.Only scores obtained are between 3 to 8.

# %% [markdown]
# # Data Visualisation:

# %%
for i in df.columns:
    plt.figure(figsize=(10,5))
    sns.lineplot(data=df,x=i,y='quality')
    plt.show()

# %% [markdown]
# Outcome:
# 1. For quality vs fixed acidity graph there is no specific trend i.e increaing or decreasing.
# 2. For quality vs volatile acidity graph there is downward trend i.e quality decreases with increase in volatile acidity.
# 3. For quality vs citric acid graph there is increasing trend i.e quality increases with increase in citric acid.
# 4. For quality vs residual sugar graph there is no specific trend i.e increaing or decreasing.
# 5. For quality vs chlorides graph there is downward trend i.e quality decreases with increase in chlorides.
# 6. For quality vs free sulfhur dioxide graph quality decreases upto certain value of free sulfhur dioxide and then increases.
# 7. For quality vs total sulfhur dioxide graph quality decreases upto certain value of total sulfhur dioxide and then increases.
# 8. For quality vs density graph there is no specific trend i.e increaing or decreasing.
# 9. For quality vs pH graph there is no specific trend i.e increaing or decreasing.
# 10. For quality vs sulphates graph there is no specific trend i.e increaing or decreasing.
# 11. For quality vs alochol graph there is increasing trend i.e quality increases with increase in alcohol.

# %% [markdown]
# # To check correlation

# %%
df.corr()['quality'].sort_values()
# Out:
# volatile acidity       -0.390558
# total sulfur dioxide   -0.185100
# density                -0.174919
# chlorides              -0.128907
# pH                     -0.057731
# free sulfur dioxide    -0.050656
# residual sugar          0.013732
# fixed acidity           0.124052
# citric acid             0.226373
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),cmap='viridis',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Observation:
# Light shades are highly correlated.
#
# Alochol is highly positively correlated with target.
# Volatile Acidity is highly negatively correlated with target.

# %% [markdown]
# # Checking Skewness:

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
#Distribution plot
for i in df.columns:
    sns.distplot(df[i])
    plt.show()

# %% [markdown]
# Outcome:
# Residual Sugar,chlorides,sulphates are heavily skewed

# %% [markdown]
# # Outliers Checking:

# %%
df.plot(kind='box',subplots=True,layout=(3,4),figsize=(10,10))
# Out:
# fixed acidity              AxesSubplot(0.125,0.657941;0.168478x0.222059)
# volatile acidity        AxesSubplot(0.327174,0.657941;0.168478x0.222059)
# citric acid             AxesSubplot(0.529348,0.657941;0.168478x0.222059)
# residual sugar          AxesSubplot(0.731522,0.657941;0.168478x0.222059)
# chlorides                  AxesSubplot(0.125,0.391471;0.168478x0.222059)
# free sulfur dioxide     AxesSubplot(0.327174,0.391471;0.168478x0.222059)
# total sulfur dioxide    AxesSubplot(0.529348,0.391471;0.168478x0.222059)
# density                 AxesSubplot(0.731522,0.391471;0.168478x0.222059)
# pH                            AxesSubplot(0.125,0.125;0.168478x0.222059)
# sulphates                  AxesSubplot(0.327174,0.125;0.168478x0.222059)
# alcohol                    AxesSubplot(0.529348,0.125;0.168478x0.222059)
# quality                    AxesSubplot(0.731522,0.125;0.168478x0.222059)
# dtype: object

# %% [markdown]
# From the above outcome we can see alcohol,citric acid has very less outliers and sulphates,density,chllorides and residual sugar has more outliers while total sulphur dioxide,pH,volatile acidity and fixed acidity has outliers very close to the wick.

# %% [markdown]
# # Data Preprocessing:

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#           45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#          106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#          151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#          244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#          354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#          459,  467,  480,  480,  494,  515,  517,  544,  554,  554,  555,
#          555,  557,  557,  568,  584,  588,  591,  595,  608,  614,  636,
#          639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
#          690,  692,  692,  695,  723,  724,  730,  754,  776,  777,  795,
#          821,  832,  836,  837,  889,  899,  911,  917,  923,  925,  926,
#          982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081,
#         1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244,
# ...

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.shape[0]
# Out:
# 1599

# %%
df_new.shape[0]
# Out:
# 1451

# %%
data_loss=(1599-1451)/1599*100
data_loss
# Out:
# 9.255784865540964

# %% [markdown]
# Since only 9% data is lost due to ouliers removal we can consider to remove outliers

# %%
#independent column
x=df_new.iloc[:,:-1]

# %%
#target
y=df_new.iloc[:,-1]

# %% [markdown]
# # Transforming Data to remove skewness:

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-0.46787818,  1.05573967, -1.52450588, ...,  1.36086042,
#         -0.58965734, -1.12042399],
#        [-0.17080535,  1.91974976, -1.52450588, ..., -0.81650738,
#          0.45152416, -0.5303401 ],
#        [-0.17080535,  1.35706712, -1.24543379, ..., -0.38097654,
#          0.22000451, -0.5303401 ],
#        ...,
#        [-1.45100718, -0.00286664, -0.66625579, ...,  0.74685493,
#          0.93043194,  0.74288203],
#        [-1.88546393,  0.76651828, -0.72755539, ...,  1.76243705,
#          0.666655  , -0.03416625],
#        [-1.7722373 , -1.33320495,  1.07130142, ...,  0.53899166,
#          0.29909273,  0.74288203]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.46787818,  1.05573967, -1.52450588, ...,  1.36086042,
#         -0.58965734, -1.12042399],
#        [-0.17080535,  1.91974976, -1.52450588, ..., -0.81650738,
#          0.45152416, -0.5303401 ],
#        [-0.17080535,  1.35706712, -1.24543379, ..., -0.38097654,
#          0.22000451, -0.5303401 ],
#        ...,
#        [-1.45100718, -0.00286664, -0.66625579, ...,  0.74685493,
#          0.93043194,  0.74288203],
#        [-1.88546393,  0.76651828, -0.72755539, ...,  1.76243705,
#          0.666655  , -0.03416625],
#        [-1.7722373 , -1.33320495,  1.07130142, ...,  0.53899166,
#          0.29909273,  0.74288203]])

# %% [markdown]
# #classifying wine quality as good or bad based on its quality.
# #"Bad"--->0 if quality of wine lies in below 7
# #"Good"--->1 if quality of wine is 7 or above.

# %%
y=y.apply(lambda x:1 if x>6 else 0)

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1451, dtype: int64

# %%
y.value_counts()
# Out:
# 0    1250
# 1     201
# Name: quality, dtype: int64

# %% [markdown]
# # Balancing the dataset

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()
trainx,trainy=smt.fit_resample(x,y)

# %%
trainy.value_counts()
# Out:
# 0    1250
# 1    1250
# Name: quality, dtype: int64

# %%
trainx
# Out:
# array([[-0.46787818,  1.05573967, -1.52450588, ...,  1.36086042,
#         -0.58965734, -1.12042399],
#        [-0.17080535,  1.91974976, -1.52450588, ..., -0.81650738,
#          0.45152416, -0.5303401 ],
#        [-0.17080535,  1.35706712, -1.24543379, ..., -0.38097654,
#          0.22000451, -0.5303401 ],
#        ...,
#        [ 0.10869813, -1.66254876,  0.50594659, ...,  0.52939493,
#          1.10516733,  1.06558032],
#        [ 1.08438839, -1.68297262,  1.35319511, ..., -2.45729274,
#          0.0726142 ,  1.31397519],
#        [ 1.29050889, -0.14958249,  1.62506812, ..., -1.59423839,
#          0.28519595,  1.31135777]])

# %% [markdown]
# # Since our outcome has only two variable we will use binary classification model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print('At random state',i,'The model performs very well')
        print('Training Accuracy Score is:',round(accuracy_score(y_train,pred_train)*100,1))
        print('Testing Accuracy Score is:',round(accuracy_score(y_test,pred_test)*100,1))
        print('\n')
# Out:
# At random state 14 The model performs very well
# Training Accuracy Score is: 82.8
# Testing Accuracy Score is: 82.8
#
#
# At random state 69 The model performs very well
# Training Accuracy Score is: 83.0
# Testing Accuracy Score is: 83.0
#
#
# At random state 141 The model performs very well
# Training Accuracy Score is: 82.4
# Testing Accuracy Score is: 82.4
#
#
# At random state 205 The model performs very well
# Training Accuracy Score is: 83.0
# Testing Accuracy Score is: 83.0
#
#
# At random state 208 The model performs very well
# Training Accuracy Score is: 82.8
# Testing Accuracy Score is: 82.8
#
#
# At random state 209 The model performs very well
# Training Accuracy Score is: 83.0
# Testing Accuracy Score is: 83.0
#
#
# At random state 223 The model performs very well
# Training Accuracy Score is: 82.6
# Testing Accuracy Score is: 82.6
#
#
# At random state 238 The model performs very well
# Training Accuracy Score is: 82.8
# Testing Accuracy Score is: 82.8
#
#
# ...

# %%
#selecting random state=67
x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,random_state=67,test_size=0.20)

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.42      0.45       246
#            1       0.51      0.58      0.54       254
#
#     accuracy                           0.50       500
#    macro avg       0.50      0.50      0.50       500
# weighted avg       0.50      0.50      0.50       500

# %% [markdown]
# # Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier() 
dtc.fit(x_train,y_train)
dtcpred=dtc.predict(x_test)
dtc.score(x_train,y_train)
print('accuracy score:',accuracy_score(y_test,dtcpred))
print(classification_report(y_test,dtcpred))
# Out:
# accuracy score: 0.886
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88       246
#            1       0.87      0.91      0.89       254
#
#     accuracy                           0.89       500
#    macro avg       0.89      0.89      0.89       500
# weighted avg       0.89      0.89      0.89       500

# %%
dtctrain=dtc.predict(x_train)
print('Training Accuracy Score is:',round(accuracy_score(y_train,dtctrain)*100,1))
print('Testing Accuracy Score is:',round(accuracy_score(y_test,dtcpred)*100,1))
# Out:
# Training Accuracy Score is: 100.0
# Testing Accuracy Score is: 88.6

# %% [markdown]
# # Cross Validation Of the Model:

# %%
from sklearn.model_selection import cross_val_score
for k in range(2,10):
    cv_score=cross_val_score(dtc,trainx,trainy,cv=k)
    cv_mean=cv_score.mean()
    print('At crossfold=',k,'the cv score is',cv_mean)
    print('training score :',accuracy_score(y_train,dtctrain))
    print('testing score :',accuracy_score(y_test,dtcpred))
    print('\n')
# Out:
# At crossfold= 2 the cv score is 0.808
# training score : 1.0
# testing score : 0.886
#
#
# At crossfold= 3 the cv score is 0.8671924405253709
# training score : 1.0
# testing score : 0.886
#
#
# At crossfold= 4 the cv score is 0.8692
# training score : 1.0
# testing score : 0.886
#
#
# At crossfold= 5 the cv score is 0.8779999999999999
# training score : 1.0
# testing score : 0.886
#
#
# At crossfold= 6 the cv score is 0.883181916005657
# training score : 1.0
# testing score : 0.886
#
#
# At crossfold= 7 the cv score is 0.8919959045070541
# training score : 1.0
# testing score : 0.886
#
#
# At crossfold= 8 the cv score is 0.8843491439338085
# training score : 1.0
# testing score : 0.886
#
#
# At crossfold= 9 the cv score is 0.8771740730159555
# training score : 1.0
# testing score : 0.886

# %% [markdown]
# Selecting cv=7

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
svc=SVC()                         
svc.fit(x_train,y_train)
svcpred=svc.predict(x_test)
svc.score(x_train,y_train)
print('accuracy score:',accuracy_score(y_test,svcpred))
print(confusion_matrix(y_test,svcpred))
print(classification_report(y_test,svcpred))
# Out:
# accuracy score: 0.882
# [[207  39]
#  [ 20 234]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.88       246
#            1       0.86      0.92      0.89       254
#
#     accuracy                           0.88       500
#    macro avg       0.88      0.88      0.88       500
# weighted avg       0.88      0.88      0.88       500

# %%
svctrain=svc.predict(x_train)
print('Training Accuracy Score is:',round(accuracy_score(y_train,svctrain)*100,1))
print('Testing Accuracy Score is:',round(accuracy_score(y_test,svcpred)*100,1))
# Out:
# Training Accuracy Score is: 91.5
# Testing Accuracy Score is: 88.2

# %%
from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(svc,trainx,trainy,cv=7)
cv_mean=cv_score.mean()
print('the cv score is',cv_mean)
print('training score :',accuracy_score(y_train,svctrain))
print('testing score :',accuracy_score(y_test,svcpred))
# Out:
# the cv score is 0.8683663409497876
# training score : 0.915
# testing score : 0.882

# %% [markdown]
# # K-Nearest Neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier
kmn=KNeighborsClassifier()
from sklearn.model_selection import GridSearchCV
parameters={'n_neighbors':[3,5,7,9,11,23,37]}
kmn=KNeighborsClassifier()
clf=GridSearchCV(kmn,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'n_neighbors': 3}

# %%
from sklearn.neighbors import KNeighborsClassifier
kmn=KNeighborsClassifier(n_neighbors=3)
kmn.fit(x_train,y_train)
kmnpred=kmn.predict(x_test)
kmn.score(x_train,y_train)
print('accuracy score:',accuracy_score(y_test,kmnpred))
print(confusion_matrix(y_test,kmnpred))
print(classification_report(y_test,kmnpred))
# Out:
# accuracy score: 0.91
# [[202  44]
#  [  1 253]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90       246
#            1       0.85      1.00      0.92       254
#
#     accuracy                           0.91       500
#    macro avg       0.92      0.91      0.91       500
# weighted avg       0.92      0.91      0.91       500

# %%
kmntrain=kmn.predict(x_train)
print('Training Accuracy Score is:',round(accuracy_score(y_train,kmntrain)*100,1))
print('Testing Accuracy Score is:',round(accuracy_score(y_test,kmnpred)*100,1))
# Out:
# Training Accuracy Score is: 95.3
# Testing Accuracy Score is: 91.0

# %%
#checking cross val score
from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(kmn,trainx,trainy,cv=7)
cv_mean=cv_score.mean()
print('the cv score is',cv_mean)
print('training score :',accuracy_score(y_train,kmntrain))
print('testing score :',accuracy_score(y_test,kmnpred))
print('\n')
# Out:
# the cv score is 0.8719756058848119
# training score : 0.953
# testing score : 0.91

# %% [markdown]
# # Ramdom Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
parameters={'n_estimators':[100,200,300,350],'max_features':['auto','sqrt','log2'],'max_depth':[5,10]}
rf=RandomForestClassifier()
rfg=GridSearchCV(rf,parameters)
rfg.fit(x_train,y_train)
print(rfg.best_params_)
# Out:
# {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 200}

# %%
rf=RandomForestClassifier(n_estimators=200,max_features='sqrt',max_depth=5)
rf.fit(x_train,y_train)
rf_test_pred=rf.predict(x_test)

# %%
print('accuracy score:',accuracy_score(y_test,rf_test_pred))
print(confusion_matrix(y_test,rf_test_pred))
print(classification_report(y_test,rf_test_pred))
# Out:
# accuracy score: 0.858
# [[202  44]
#  [ 27 227]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85       246
#            1       0.84      0.89      0.86       254
#
#     accuracy                           0.86       500
#    macro avg       0.86      0.86      0.86       500
# weighted avg       0.86      0.86      0.86       500

# %%
rftrain=rf.predict(x_train)
print('Training Accuracy Score is:',round(accuracy_score(y_train,rftrain)*100,1))
print('Testing Accuracy Score is:',round(accuracy_score(y_test,rf_test_pred)*100,1))
# Out:
# Training Accuracy Score is: 90.2
# Testing Accuracy Score is: 85.8

# %%
#checking cross val score
from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(rf,trainx,trainy,cv=7)
cv_mean=cv_score.mean()
print('the cv score is',cv_mean)
print('Training Accuracy Score is:',round(accuracy_score(y_train,rftrain)*100,1))
print('Testing Accuracy Score is:',round(accuracy_score(y_test,rf_test_pred)*100,1))
# Out:
# the cv score is 0.858376870301193
# Training Accuracy Score is: 90.2
# Testing Accuracy Score is: 85.8

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# Selecting Random Forest as our final model since cv score and testing score is almost equal.

# %% [markdown]
# # ROC AUC CURVE

# %%
from sklearn.metrics import plot_roc_curve

# %%
plot_roc_curve(rf,x_test,y_test)
plt.title('ROC AUC PLOT')
plt.show()

# %% [markdown]
# AUC score is 95%

# %%
original=np.array(y_test)
predicted=np.array(rf_test_pred)
df_com=pd.DataFrame({'Original':original,'Predicted':predicted},index=range(len(original)))
df_com
# Out:
#      Original  Predicted
# 0           1          1
# 1           1          1
# 2           1          1
# 3           1          1
# 4           1          1
# ..        ...        ...
# 495         1          1
# 496         0          0
# 497         1          1
# 498         1          1
# 499         1          1
#
# [500 rows x 2 columns]

# %% [markdown]
# # SAVING BEST MODEL

# %%
import joblib

# %%
joblib.dump(rf,'rffile.obj')
# Out:
# ['rffile.obj']
